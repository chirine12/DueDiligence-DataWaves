# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import fitz

# %%
from huggingface_hub import login
login(token="your_token")

# %%
# =======================
# 🛠️ Install Dependencies
# =======================
# !pip install transformers PyMuPDF --quiet

# ===========================
# 🔌 Mount Google Drive
# ===========================
from google.colab import drive
drive.mount('/content/drive')

# ===========================
# 📄 Extract Text from PDF
# ===========================
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page_num in range(doc.page_count):
        if page_num == 0 or page_num in [16, 17, 18]:
            continue
        page = doc.load_page(page_num)
        text += page.get_text()
    return text

# ===========================
# ✂️ Split Text into Chunks
# ===========================
def split_text_into_chunks(text, chunk_size=1000, overlap=200):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        for i in range(end-1, max(start, end-100), -1):
            if text[i] in ['.', '?', '!'] and (i+1 == len(text) or text[i+1].isspace()):
                end = i + 1
                break
        chunks.append(text[start:end])
        start = end - overlap if end - overlap > start else end
    return chunks

# ===========================
# 🧠 Load New Question Generator Model
# ===========================
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

model_name = "valhalla/t5-small-qg-hl"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# ===========================
# ❓ Generate Questions from Highlighted Text
# ===========================
def generate_questions(text, num_questions=5):
    # We use <hl> to highlight a sentence in a passage
    sentences = text.split('. ')
    questions = []

    for i, sentence in enumerate(sentences):
        if len(sentence.strip().split()) < 6:
            continue

        # Highlight the sentence
        highlighted = text.replace(sentence, f"<hl> {sentence.strip()} <hl>")

        input_text = f"generate question: {highlighted}"
        inputs = tokenizer.encode(input_text, return_tensors="pt", truncation=True, max_length=512).to(device)

        outputs = model.generate(
            inputs,
            max_length=64,
            num_beams=4,
            early_stopping=True
        )

        question = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()
        if question.endswith("."):
            question = question[:-1] + "?"
        questions.append(question)

        if len(questions) >= num_questions:
            break

    return questions

# ===========================
# 🔁 Full Process on PDF
# ===========================
def generate_questions_from_pdf(pdf_path, questions_per_chunk=5):
    print("🔍 Extracting text...")
    document_text = extract_text_from_pdf(pdf_path)

    print("✂️ Splitting text...")
    chunks = split_text_into_chunks(document_text, chunk_size=1200)

    all_questions = []
    for i, chunk in enumerate(chunks):
        print(f"✨ Processing chunk {i+1}/{len(chunks)}...")
        qs = generate_questions(chunk, questions_per_chunk)
        all_questions.extend([f"Q{i+1}.{j+1}: {q}" for j, q in enumerate(qs)])
        print("\n".join(qs))
        print("--------")

    return all_questions

# ===========================
# 🧪 Run Example
# ===========================
pdf_path = "/content/drive/My Drive/DueDilDocuments/ey-token-due-diligence-a-structured-approach-to-evaluate-digital-asset-risk.pdf"
questions = generate_questions_from_pdf(pdf_path)

# Save to file
with open("/content/drive/My Drive/generated_questions4.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(questions))

print(f"\n✅ Total Questions: {len(questions)}")
print("📁 Saved to /content/drive/My Drive/generated_questions4.txt")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 29.2 MB/s eta 0:00:00
# Mounted at /content/drive
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# 🔍 Extracting text...
# ✂️ Splitting text...
# ✨ Processing chunk 1/61...
# What is a structured approach to evaluate digital asset risk?
# What is the general token due diligence framework?
# What is the definition of a token due diligence framework?
# What is the definition of a token due diligence framework?
# What does Cybersecurity 13 6.1 Governance and operational security 13 7. Auditability 14 7.1 Auditability and ownership 14 8. Summary 15 9?
# --------
# ✨ Processing chunk 2/61...
# What is the key to cybersecurity 13 6.1 Governance and operational security 13 7?
# What is the key to auditability?
# What does Cybersecurity 13 6.1 Governance and operational security 13 7?
# What may be difficult to ascertain quality from noise, memetic and groupthink from adoption?
# What may a small subset revolutionize the world as innovative disintermediation tools?
# --------
# ✨ Processing chunk 3/61...
# What are some regulatory bodies known to require coin-listing policies to meet rigorous standards?
# What does each of these players have its own risk tolerance thresholds?
# What do we define as a general representation of our methodology?
# What will we dive into several sub-risk categories for each pillar?
# --------
# ✨ Processing chunk 4/61...
# What is DeFi's current state?
# Why are risk disclosures prevalent in regulated consumer financial products absent in cryptocurrencies?
# What should be done for proper baseline coverage of decentralized finance?
# What is a structured approach to ev?
# --------
# ✨ Processing chunk 5/61...
# What is a structured approach to evaluate digital asset risk 2?
# What are the participants behind the code at the social layer often overlooked?
# What is a foundational consideration for a token?
# What is a foundational consideration for a token?
# What are some of the reasons teams decide to build anonymously?
# --------
# ✨ Processing chunk 6/61...
# What are examples of projects with public founders that have sustained billions of dollars in total value deposited into the protocols they have built?
# What are some of the projects with public founders that have built great user experiences?
# What does public leadership help assuage investor concerns?
# What are some public founders known to have experienced major faults in execution?
# What did some public founders use to market their centralized lending platform?
# --------
# ✨ Processing chunk 7/61...
# What did anonymous founders use to increase leverage or misappropriate funds?
# How have anonymous founders demonstrated more mixed track records?
# Who has been the most successful anonymous founder to date?
# What has been a slew of application layer protocols with anonymous founders?
# What is the problem with protocols with anonymous founders?
# --------
# ✨ Processing chunk 8/61...
# What is the purpose of a due diligence review?
# What is more appropriate to use this criterion as a means of gaining comfort that there is a single individual who can be assigned accountability?
# What is the criterion of a due diligence review?
# What is the basis in which any application-level token must operate?
# What are several decisions made based on?
# --------
# ✨ Processing chunk 9/61...
# What does the Nakamoto Coefficient mean?
# What is a difficult question to answer?
# What does the value proposition of public blockchains remain?
# What is the Nakamoto Coeffic?
# --------
# ✨ Processing chunk 10/61...
# What are the Subsystems of blockchains 5 Nakamoto Coefficient vs?
# What does Srinivasan call the “subsystem” level?
# What does Srinivasan consider subsystems of blockchains?
# --------
# ✨ Processing chunk 11/61...
# What is the definition of a subsystem?
# What do subsystems represent?
# What is the argument that the entire system is centralized?
# What is the difference between GETH and GETH?
# What is a structured approach to evaluate digital asset risk?
# --------
# ✨ Processing chunk 12/61...
# What measures the number of unique addresses that contain an amount of the asset between a predetermined threshold Token due diligence?
# What do Avalanche and Solana demonstrate higher levels of decentralization?
# What does Centralization lead to a higher risk of collusion?
# What can a network run the risk of less than two-thirds of validators online at any time?
# What does Centralization compromise credible neutrality?
# --------
# ✨ Processing chunk 13/61...
# What is the finality of BNB Chain?
# What was BNB's native cryptocurrency?
# What was the result of the attack on BNB Chain?
# What is unclear about the viability of the network?
# What is another technical design risk that blockchain protocols must contend with?
# --------
# ✨ Processing chunk 14/61...
# What are trade-offs to make when bridging assets cross-chain?
# How many ETH was the Wormhole Bridge exploited for?
# What happens when ETH tokens are minted on Solana via Wormhole?
# What resulted in the same amount of wETH on Solana unbacked?
# What did the Wormhole Bridge create?
# --------
# ✨ Processing chunk 15/61...
# What required a significant capital injection from Wormhole’s parent company?
# What is a significant impact on scalability and security?
# What can modular vs. monolithic blockchains have a significant impact on?
# What does modularity mean?
# What is the name of Ethereum's commitment to modular architecture principles?
# --------
# ✨ Processing chunk 16/61...
# What is a risk to holders of both tokens issued through smart contracts?
# What is Governance generally designed into the operation of the network or decentralized application?
# What are token holders able to coordinate efforts to change, update and protect?
# How many tokens did the attacker staking rewards?
# What did the attack break the intent of the airdrop rules?
# --------
# ✨ Processing chunk 17/61...
# What led to a contentious governance vote?
# What did eal with the issue lead to a contentious governance vote?
# What was Proposal 16, which confiscated a single individual's wealth?
# What did many consider the action a blight on?
# What did the attacker take advantage of?
# --------
# ✨ Processing chunk 18/61...
# What did the community vote to protect themselves?
# What is a key factor in considering governance?
# What is the most widely used general-purpose smart contract blockchain?
# --------
# ✨ Processing chunk 19/61...
# What is the lion's share of development activity?
# What is an ongoing issue despite the transparency of smart contracts written in Solidity?
# What is an efficient way to leverage the wisdom of the crowd?
# What does the SCRT offer?
# What is one example of a flash loan exploit?
# --------
# ✨ Processing chunk 20/61...
# What does a flash loan exploit allow testing against?
# What is one common type of exploit?
# What is a flash loan exploit?
# What does a flash loan showcase?
# What do Flash loans do?
# --------
# ✨ Processing chunk 21/61...
# What is a structured approach to evaluate digital asset risk?
# What happened when a malicious entity borrowed a significant amount of capital from a lending protocol?
# What did a Sybil attack allow the user to push a nefarious proposal through?
# What resulted in the entity's ability to drain the token's primary liquidity pool?
# What do companies provide smart contract auditing services?
# --------
# ✨ Processing chunk 22/61...
# How many smart contract risks are there?
# What do companies provide smart contract auditing services?
# What do auditing services do?
# What does the availability of a report not necessarily indicate?
# What is important to consider vulnerabilities in popular code libraries?
# --------
# ✨ Processing chunk 23/61...
# What could have allowed exploiters to drain the entire TVL of several protocols?
# What was the cause of the rounding error?
# Why was this attack not feasible on Ethereum?
# What does the Ethereum Foundation fund?
# Who is the research team composed of?
# --------
# ✨ Processing chunk 24/61...
# What is the consensus layer client team?
# What is the base fee?
# What is the base fee?
# What does the base fee adjusting mean?
# How long did EIP-1559 take to implement from its initial code repository creation?
# --------
# ✨ Processing chunk 25/61...
# What does the community align with?
# What is the risk of malicious code making its way into production?
# What can be said for newer protocols that do not have the same levels of engagement?
# What do token governance processes need to understand?
# What is a structured approach to evaluate digital asset risk?
# --------
# ✨ Processing chunk 26/61...
# What does iness development have?
# What can be considered higher risk protocol management because it allows unilateral decision-making?
# What may be overlooked by maintaining a centralized development team?
# What does organic community development have a strong correlation to economic sustainability?
# What is the Terra Luna saga?
# --------
# ✨ Processing chunk 27/61...
# What is an important factor to consider?
# What do DAOs typically set community funds aside from the token generation event?
# What can on-chain DAO governance proposals be used to implement protocol changes as needed?
# What do DAOs give token holders varying degrees of governance rights to vote on?
# --------
# ✨ Processing chunk 28/61...
# What do DAOs offer monetary incentives in a consulting-like capacity?
# What is an important way for DAOs to develop new products that fit the community's needs?
# How is a sizable cash runway mandatory for protocol longevity?
# What do DAOs tend to coincide with significant speculation on governance token prices?
# What can token price serve as a barometer for the marginal new user or speculator?
# --------
# ✨ Processing chunk 29/61...
# What may be an attractor for greater development and community engagement?
# What do patterns of behavior suggest that governance is as robust as the core team’s credibility and track record?
# When a community believes it passed a vote, one must consider whether the core members will follow through with the action?
# What is a core component of a token?
# What does a protocol's token provide?
# --------
# ✨ Processing chunk 30/61...
# What metrics can a token be evaluated based on?
# What is a structured approach to evaluate digital asset risk economic activity and utility supporting its valuation?
# What is important to consider when considering TVL?
# What does Uniswap have a high TVL?
# --------
# ✨ Processing chunk 31/61...
# What do Layer-1 protocols have?
# What does BTC mean for a proof of work chain?
# What does Bitcoin have a hard cap?
# What does a token holder not exclusively interpret whether an asset is net inflationary?
# --------
# ✨ Processing chunk 32/61...
# What is ETH burned per transaction than issued?
# What did ETH reduce its inflation rate by 90%?
# What did the transition from proof of work to proof of stake reduce mandatory sell pressure?
# What can L1 protocols use experimental economic design mechanisms?
# What was Terra unique in that an algorithmic stablecoin was embedded into the protocol design?
# --------
# ✨ Processing chunk 33/61...
# What is the name of the ally that minted UST?
# How much would UST be burned to mint UST?
# What happened to the design of UST?
# What caused other more-leveraged Luna traders to sell via forced liquidations?
# What did the market cap of Luna have always been greater than the value of UST?
# --------
# ✨ Processing chunk 34/61...
# What is the value profile of an L1 blockchain?
# What do DAOs deliver to their users?
# What does L1 blockchains have a more visible and endogenous revenue capture model?
# What do DAO tokens need to exhibit utility and revenue capture?
# What is the difference between utility and revenue capture?
# --------
# ✨ Processing chunk 35/61...
# What level may not be present in the tokens?
# What is a structured approach to evaluate digital asset risk?
# What exemplifies Solana ecosystem tokens?
# What can be difficult for DAOs to gain tangible value due to prevailing securities laws?
# What have some communities voted on to work around cash flow distribution?
# --------
# ✨ Processing chunk 36/61...
# What is a combination of computation, storage, verifying proofs and data availability?
# What does the greater the usage volume, the greater the revenue?
# What does fees flow dictate?
# What do some L1s take a percentage for their own treasury in a more for profit manner?
# What is the relation between fees and inflation?
# --------
# ✨ Processing chunk 37/61...
# What is a strong indicator of user adoption, usage and demand for blockspace?
# What is the difference between a protocol with 100% inflation and 1% fees?
# What do protocol revenue, market cap to revenue, stock to flow and staking yield are helpful metrics?
# What happens to a non-staker?
# What does the marginal staker receive their share of the total market cap?
# --------
# ✨ Processing chunk 38/61...
# What is a structured approach to evaluate digital asset risk?
# What does User X hold token Y at $1b market cap?
# What is a 50% annual return from inflation and fees?
# What are some financial metrics that may include TVL to market cap and total transactions?
# What does there not have a direct link between any of these and yield for stakers?
# --------
# ✨ Processing chunk 39/61...
# What does tween any of the DAOs?
# What does one protocol have low transactions but high fee value?
# How should each L1 protocol warrant its own analysis?
# What does DAOs generate revenue when users interact with smart contracts?
# What does each subsector have its own drivers?
# --------
# ✨ Processing chunk 40/61...
# What is the difference between in-game advertisements and non-fungible tokens?
# What does art depend more on primary issuance of non-fungible tokens?
# What may be partnerships with metaverses or games?
# What is the key to assessing the dilutive path of token issuance over time?
# What is the underlying sustainability of its userbase, fees and supply of DAOs?
# --------
# ✨ Processing chunk 41/61...
# What are the 22 s that seek to replace sovereign currencies and those that represent an investment in an enterprise?
# What did the Howey Test draw a direct connection to?
# How is the Howey Test still the main way to assess digital assets from a securities perspective?
# What is Forman's name?
# What is Forman's definition of a security?
# --------
# ✨ Processing chunk 42/61...
# What is Forman's name?
# What is Forman's name?
# What do tokens like ETH have practical uses that may transcend speculation or expectation of profits for holders?
# What is Gary Gensler's goal to treat almost all digital assets?
# What has the SEC primarily applied to evaluate digital asset risk?
# --------
# ✨ Processing chunk 43/61...
# What is a structured approach to evaluate digital asset risk?
# What did Gensler say the SEC should remain technology neutral in its application of securities law?
# What did Gensler say his SEC stands ready to support crypto natives' path to compliance?
# What has led to conflicting guidance as to how digital assets fit under the Howey Test?
# What did the courts say Ripple Labs did not violate securities law?
# --------
# ✨ Processing chunk 44/61...
# What did the Howey Test say about digital assets?
# What did courts rule in favor of Ripple Labs?
# What did the judge consider blind bid/ask transactions?
# What did the Howey Test rule in favor of Ripple Labs?
# --------
# ✨ Processing chunk 45/61...
# What is the Howey Test?
# What is a prong of the Howey Test?
# What does the Howey Test mean?
# What are some of the messages that are often amplified by paid advertisers?
# What happens when non-insiders experience significant loss as exit liquidity for those who were most vocal about the potential for making profits?
# --------
# ✨ Processing chunk 46/61...
# What is important to pay attention to how the project team conducts itself in public forums?
# What is important to pay attention to how the project team conducts itself in public forums?
# What is it pragmatic to avoid tokens that provide large token allocations to founders?
# What is the old adage of “if it sounds too good to be true, it probably is” still true in cryptocurrency markets?
# What is the old adage of if it sounds too good to be true?
# --------
# ✨ Processing chunk 47/61...
# What is the purpose of MiCA?
# What is the purpose of the Markets in Crypto-Assets regulation?
# What is a critical factor in understanding the risks associated with the tokens supported by them?
# What is the most likely reason that funds lost are unrecoverable?
# What is no guarantee that an exploited code flaw can be successfully remediated in a timely manner?
# --------
# ✨ Processing chunk 48/61...
# What does the Compound Comptroller contract exploit?
# What happens to the complexity of these processes?
# What do project teams dilute their ability to exercise control over the direction of their protocol in favor of decentralized, community driven governance processes?
# What happened to the Compound Finance smart contract exploit?
# What happened to the Compound Comptroller contract?
# --------
# ✨ Processing chunk 49/61...
# What was the result of the incorrect distribution of COMP's governance token?
# What was the result of Comppound's governance token?
# What was the purpose of Compound's governance processes?
# What did Compound Labs implement in April 2020?
# What did Compound Labs enforc programmatic governance?
# --------
# ✨ Processing chunk 50/61...
# What may have to do with the Compound protocol?
# What does the Pause Guardian function do?
# Why was the Pause Guardian function not used to bypass community governance?
# Why was the Pause Guardian function not used to bypass community governance?
# What should be a key consideration for token holders?
# --------
# ✨ Processing chunk 51/61...
# What should be a key consideration for token holders?
# What can a protocol's history of governance proposals provide insight into?
# What is a significant vector for attack when a protocol implements a treasury wallet?
# What is a common practice for multi-sig wallets?
# How are project teams and community members not always transparent?
# --------
# ✨ Processing chunk 52/61...
# What are some of the key management practices that are important to understand?
# What is important to understand how a multi-sig wallet is implemented?
# What should be considered when evaluating risk associated with a cryptocurrency or token?
# What should be considered when evaluating risk associated with a cryptocurrency or token?
# How should the completeness and accuracy of data be tested?
# --------
# ✨ Processing chunk 53/61...
# What is a key audit consideration for a blockchain?
# What should a token holder be able to understand?
# What does the Cosmos blockchain have?
# What is the risk of a clandestine and arbitrary confiscation of account funds?
# --------
# ✨ Processing chunk 54/61...
# What is the risk of a clandestine and arbitrary confiscation of account funds by malicious entities?
# What is important for token holders to be able to audit existence, movement and ownership of digital assets?
# How is Etherscan structured?
# What should a token holder consider identifying a diverse set of scanning technologies?
# What does the existence of privacy-enabling technology on blockchains increase the risk that digital assets are used for?
# --------
# ✨ Processing chunk 55/61...
# What can a token holder's ability to accurately track balances and movement of funds?
# What is a good way to determine if a network has a way to effectively screen potentially malicious transactions?
# What is a good way to determine if a network has a way to effectively screen malicious transactions?
# How can the blockchain ecosystem be combined?
# What are different types of token holders based on their use case?
# --------
# ✨ Processing chunk 56/61...
# What are the economic models that can be combined in a seemingly endless number of ways?
# Different types of token holders will have different risk appetites based on what?
# What has led to a diverse ecosystem of application-specific chains with complex token ecosystems built atop?
# What has led to a diverse ecosystem of application-specific chains with complex token ecosystems built atop?
# What is a nontrivial task for the crypto savvy?
# --------
# ✨ Processing chunk 57/61...
# What is the purpose of arming potential token holders with a guide on how to think about token risk across the entire ecosystem?
# What is the purpose of the framework?
# What does the framework not weigh the probability of a black swan event?
# What does the framework help flagging potential exogenous and endogenous risks?
# What does pairing the general framework with a technical risk and compliance assessment produce the best results?
# --------
# ✨ Processing chunk 58/61...
# What is Ernst & Young's approach to digital asset clients?
# What has Ernst & Young LLP brought together the capabilities of our global blockchain technology team?
# What extends Ernst & Young LLP's distinction as the only professional services firm?
# What is the focus of Ernst & Young LLP?
# What does Ernst & Young LLP support?
# --------
# ✨ Processing chunk 59/61...
# What are the two main areas of regulatory compliance?
# What do we support clients that are in the early stages of designing and developing their products?
# What does our integrated digital assets team help to build?
# --------
# ✨ Processing chunk 60/61...
# What does our integrated digital assets team help to build?
# --------
# ✨ Processing chunk 61/61...
# What is a structured approach to evaluate digital asset risk?
# --------
#
# ✅ Total Questions: 283
# 📁 Saved to /content/drive/My Drive/generated_questions4.txt
